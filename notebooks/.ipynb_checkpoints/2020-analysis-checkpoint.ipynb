# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_2020 = pd.read_csv('AB_US_2020.csv', encoding='utf-8', low_memory=False)
# df_2023 = pd.read_csv('AB_US_2023.csv', encoding='utf-8', low_memory=False)
